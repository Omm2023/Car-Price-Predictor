# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('quikr_car.csv')

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
backup=car.copy()##backup to prevent the data loss

# %%
car=car[car['year'].str.isnumeric()]

# %%
car['year']=car['year'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 46.0+ KB

# %%
car['Price']
# Out:
# 0             80,000
# 1           4,25,000
# 2      Ask For Price
# 3           3,25,000
# 4           5,75,000
#            ...
# 886         3,00,000
# 888         2,60,000
# 889         3,90,000
# 890         1,80,000
# 891         1,60,000
# Name: Price, Length: 842, dtype: object

# %%
car['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
car=car[car['Price'] != 'Ask For Price']

# %%
car['Price']
# Out:
# 0        80,000
# 1      4,25,000
# 3      3,25,000
# 4      5,75,000
# 6      1,75,000
#          ...
# 886    3,00,000
# 888    2,60,000
# 889    3,90,000
# 890    1,80,000
# 891    1,60,000
# Name: Price, Length: 819, dtype: object

# %%
car['Price']=car['Price'].str.replace(',','').astype(int)# in case of string values where the operation need to be done .str is used

# %%
car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0)

# %%
car['kms_driven']
# Out:
# 0        45,000
# 1            40
# 3        28,000
# 4        36,000
# 6        41,000
#          ...
# 886    1,32,000
# 888      27,000
# 889      40,000
# 890      Petrol
# 891      Petrol
# Name: kms_driven, Length: 819, dtype: object

# %%
car['kms_driven']=car['kms_driven'].replace(',','')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.8+ KB

# %%
car=car[car['kms_driven'].str.isnumeric()]##its requirted as here we delete the data which are not numeric

# %%
car['kms_driven']=car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int64
#  3   Price       17 non-null     int64
#  4   kms_driven  17 non-null     int64
#  5   fuel_type   17 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 952.0+ bytes

# %%
backup['fuel_type']=car['fuel_type']

# %%
car['fuel_type']
# Out:
# 1      Diesel
# 15     Diesel
# 215    Diesel
# 222    Diesel
# 302    Petrol
# 364    Diesel
# 381    Diesel
# 382    Diesel
# 387    Diesel
# 427    Diesel
# 470    Petrol
# 485    Diesel
# 577    Diesel
# 702    Petrol
# 721    Petrol
# 738    Petrol
# 762    Petrol
# Name: fuel_type, dtype: object

# %%
car['name'].str.split(' ').str.slice(0,3).str.join('')
# Out:
# 1      MahindraJeepCL550
# 15     MahindraJeepCL550
# 215       MahindraJeepMM
# 222    MahindraJeepCL550
# 302    MarutiSuzukiSwift
# 364       MahindraJeepMM
# 381    MahindraJeepCL550
# 382       MahindraJeepMM
# 387      ToyotaInnova2.5
# 427         NissanXTrail
# 470    MarutiSuzukiSwift
# 485    TataTigorRevotron
# 577       MahindraJeepMM
# 702       FordFigoPetrol
# 721      MarutiSuzukiZen
# 738      HyundaiCreta1.6
# 762    TataTiagoRevotorq
# Name: name, dtype: object

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int64
#  3   Price       17 non-null     int64
#  4   kms_driven  17 non-null     int64
#  5   fuel_type   17 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 1.5+ KB

# %%
car=car.reset_index(drop=True)

# %%
car.describe()
# Out:
#               year         Price  kms_driven
# count    17.000000  1.700000e+01   17.000000
# mean   2014.235294  5.369118e+05  142.294118
# std       5.921670  2.911702e+05  198.243148
# min    2004.000000  1.250000e+05    0.000000
# 25%    2009.000000  3.900000e+05    0.000000
# 50%    2018.000000  4.250000e+05   60.000000
# 75%    2019.000000  6.100000e+05  122.000000
# max    2019.000000  1.200000e+06  588.000000

# %%
car[car['Price']>6e6]
# Out:
# Empty DataFrame
# Columns: [name, company, year, Price, kms_driven, fuel_type]
# Index: []

# %%
car.to_csv('cleaned_one.csv')

# %%
x=car.drop(columns='Price')
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Fit on all possible categories
all_categories = ['Honda Civic', 'Toyota Corolla', 'Ford Focus', 'Nissan X Trail Select Variant', 'Tata Tigor Revotron XZ', 'Tata Tiago Revotorq XZ']
le.fit(all_categories)
# Out:
# LabelEncoder()

# %%
ohe.categories_
# Out:
# [array(['Ford Figo Petrol Titanium', 'Hyundai Creta 1.6 SX',
#         'Mahindra Jeep CL550 MDI', 'Mahindra Jeep MM 550 XDB',
#         'Maruti Suzuki Swift Dzire Tour VXi',
#         'Maruti Suzuki Swift VXi 1.2 ABS BS IV',
#         'Maruti Suzuki Zen Estilo LXI Green CNG',
#         'Nissan X Trail Select Variant', 'Tata Tiago Revotorq XZ',
#         'Tata Tigor Revotron XZ', 'Toyota Innova 2.5 E MS 7 STR BS IV'],
#        dtype=object),
#  array(['Ford', 'Hyundai', 'Mahindra', 'Maruti', 'Nissan', 'Tata',
#         'Toyota'], dtype=object),
#  array(['Diesel', 'Petrol'], dtype=object)]

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')## TRANSFORM THE COLUMNS AND PASS THE REMAINGF TO CINVERT THE DATA and in ohe thje parameter needs to be passed

# %%
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
encoder.fit(train_data[['car_model']])
transformed_data = encoder.transform(test_data[['car_model']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
# ----> 2 encoder.fit(train_data[['car_model']])
#       3 transformed_data = encoder.transform(test_data[['car_model']])
#
# NameError: name 'train_data' is not defined

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)## pipe the data TO LR

# %%
pipe.fit(x_train,y_train)##transfer and send the data directly
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ford Figo Petrol Titanium', 'Hyundai Creta 1.6 SX',
#        'Mahindra Jeep CL550 MDI', 'Mahindra Jeep MM 550 XDB',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Fit on all possible categories
all_categories = ['Honda Civic', 'Toyota Corolla', 'Ford Focus', 'Nissan X Trail Select Variant', 'Tata Tigor Revotron XZ', 'Tata Tiago Revotorq XZ']
le.fit(all_categories)
# Out:
# LabelEncoder()

# %%
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)## here the encoder is one hotencoder  and we use the ignoire comand to ignore the unknown data spare output as false
encoder.fit(train_data[['car_model']])
transformed_data = encoder.transform(test_data[['car_model']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)## here the encoder is one hotencoder  and we use the ignoire comand to ignore the unknown data spare output as false
# ----> 2 encoder.fit(train_data[['car_model']])
#       3 transformed_data = encoder.transform(test_data[['car_model']])
#
# NameError: name 'train_data' is not defined

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.22780258022450184

# %%
scores=[]
for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# np.int64(506)

# %%
scores[np.argmax(scores)]##percentage of score
# Out:
# 0.9970332248406488

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=np.argmax(scores))##random stae is a function that asssume sthe variable toi be considered to find the score and fit it
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.9970332248406488

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Nissan X Trail Select Variant','Nissan',2019,300,'Diesel']], columns=['name','company','year','kms_driven','fuel_type']))##pipe is used to transer the predicted data
# Out:
# array([1199962.59420185])

# %%
car
# Out:
#                                       name   company  year    Price  \
# 0                  Mahindra Jeep CL550 MDI  Mahindra  2006   425000
# 1                  Mahindra Jeep CL550 MDI  Mahindra  2006   425000
# 2                 Mahindra Jeep MM 550 XDB  Mahindra  2019   390000
# 3                  Mahindra Jeep CL550 MDI  Mahindra  2018   385000
# 4    Maruti Suzuki Swift VXi 1.2 ABS BS IV    Maruti  2019   610000
# 5                 Mahindra Jeep MM 550 XDB  Mahindra  2019   390000
# 6                  Mahindra Jeep CL550 MDI  Mahindra  2018   385000
# 7                 Mahindra Jeep MM 550 XDB  Mahindra  2006   425000
# 8       Toyota Innova 2.5 E MS 7 STR BS IV    Toyota  2012   770000
# 9            Nissan X Trail Select Variant    Nissan  2019  1200000
# 10      Maruti Suzuki Swift Dzire Tour VXi    Maruti  2011   230000
# 11                  Tata Tigor Revotron XZ      Tata  2019   650000
# 12                Mahindra Jeep MM 550 XDB  Mahindra  2004   424000
# ...
